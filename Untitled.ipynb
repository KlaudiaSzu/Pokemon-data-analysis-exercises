# %% [markdown]
# ## Pandas - Pokemon data analysis exercises

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/Klaudia/Desktop/Analiza/pokemon_data.csv')
print(df)
#print(df.head(3))
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ### Reading Data

# %%
#reading headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#read each row
print(df.iloc[3])
print(df.iloc[1:4])
# Out:
# #                                 3
# Name          VenusaurMega Venusaur
# Type 1                        Grass
# Type 2                       Poison
# Total                           625
# HP                               80
# Attack                          100
# Defense                         123
# Sp. Atk                         122
# Sp. Def                         120
# Speed                            80
# Generation                        1
# Legendary                     False
# Name: 3, dtype: object
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# ...

# %%
#specyfic row
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
#read names
for index, row in df.iterrows():
    print(index,row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran♀
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran♂
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# ...

# %%
#shows only grass type
df.loc[df['Type 1'] == "Grass"]
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 48    43                 Oddish  Grass    Poison    320   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    313   56      61       65
# 719  651              Quilladin  Grass       NaN    405   61      78       95
# 720  652             Chesnaught  Grass  Fighting    530   88     107      122
# 740  672                 Skiddo  Grass       NaN    350   66      65       48
# 741  673                 Gogoat  Grass       NaN    531  123     100       62
#
# ...

# %% [markdown]
# ### Sorting data

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
#sorting values by speed (desc)
df.sort_values('Speed', ascending=False)
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 431  386          DeoxysSpeed Forme  Psychic     NaN    600   50      95
# 315  291                    Ninjask      Bug  Flying    456   61      90
# 428  386         DeoxysNormal Forme  Psychic     NaN    600   50     150
# 154  142  AerodactylMega Aerodactyl     Rock  Flying    615   80     135
# 71    65      AlakazamMega Alakazam  Psychic     NaN    590   55      50
# ..   ...                        ...      ...     ...    ...  ...     ...
# 658  597                  Ferroseed    Grass   Steel    305   44      50
# 486  438                     Bonsly     Rock     NaN    290   50      80
# 359  328                   Trapinch   Ground     NaN    290   45     100
# 230  213                    Shuckle      Bug    Rock    505   20      10
# 495  446                   Munchlax   Normal     NaN    390  135      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'Type 1'])
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### Changes in data

# %%
#without HP
#df['Total'] =  df['Attack']+ df['Defense']+ df['Sp. Atk']+ df['Sp. Def']+ df['Speed']

# %%
df['Total'] = df['HP']+ df['Attack']+ df['Defense']+ df['Sp. Atk']+ df['Sp. Def']+ df['Speed']
df.head(6)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
# 5  5             Charmeleon   Fire     NaN    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False

# %%
#df['Total']=df.iloc[:,4:10].sum(axis=1)
#cols = list(df.columns)
#df = df[cols[0:4] + [cols[-1]]+ cols[4:12]]

# %% [markdown]
# ### Saving data

# %%
#df.to_csv('modified.csv', index= False)

# %%
#df.to_excel('modified.xlxs', index= False)

# %% [markdown]
# ### Filtering data/Regex

# %%
df.loc[df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
df.loc[(df['Type 1'] == 'Fire') & (df['Type 2'] == 'Flying')]
# Out:
#        #                       Name Type 1  Type 2  Total   HP  Attack  \
# 6      6                  Charizard   Fire  Flying    534   78      84
# 8      6  CharizardMega Charizard Y   Fire  Flying    634   78     104
# 158  146                    Moltres   Fire  Flying    580   90     100
# 270  250                      Ho-oh   Fire  Flying    680  106     130
# 730  662                Fletchinder   Fire  Flying    382   62      73
# 731  663                 Talonflame   Fire  Flying    499   78      81
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6         78      109       85    100           1      False
# 8         78      159      115    100           1      False
# 158       90      125       85     90           1       True
# 270       90      110      154     90           2       True
# 730       55       56       52     84           6      False
# 731       71       74       69    126           6      False

# %%
df.loc[(df['Type 1'] == 'Fire') & (df['HP'] > 80)]
# Out:
#        #                     Name Type 1    Type 2  Total   HP  Attack  \
# 64    59                 Arcanine   Fire       NaN    555   90     110
# 158  146                  Moltres   Fire    Flying    580   90     100
# 263  244                    Entei   Fire       NaN    580  115     115
# 270  250                    Ho-oh   Fire    Flying    680  106     130
# 542  485                  Heatran   Fire     Steel    600   91      90
# 558  499                  Pignite   Fire  Fighting    418   90      93
# 559  500                   Emboar   Fire  Fighting    528  110     123
# 615  555  DarmanitanStandard Mode   Fire       NaN    480  105     140
# 616  555       DarmanitanZen Mode   Fire   Psychic    540  105      30
# 692  631                  Heatmor   Fire       NaN    484   85      97
# 736  668                   Pyroar   Fire    Normal    507   86      68
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
second_df = df.loc[(df['Type 1'] == 'Fire') & (df['HP'] > 80)]
#second_df.to_csv('filtered.csv')

# %%
#filtering data by words they contain
df.loc[df['Name'].str.contains('Mode')]
# Out:
#        #                     Name Type 1   Type 2  Total   HP  Attack  \
# 615  555  DarmanitanStandard Mode   Fire      NaN    480  105     140
# 616  555       DarmanitanZen Mode   Fire  Psychic    540  105      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 615       55       30       55     95           5      False
# 616      105      140      105     55           5      False

# %%
# data without word 'Mega'
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 4      4           Charmander     Fire     NaN    309   39      52       43
# 5      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

# %%
df.loc[df['Type 1'].str.contains('Water|Grass',regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 9      7               Squirtle  Water     NaN    314   44      48       65
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 726  658               Greninja  Water    Dark    530   72      95       67
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 762  692              Clauncher  Water     NaN    330   50      53       62
# 763  693              Clawitzer  Water     NaN    500   71      73       88
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Name'].str.contains('ca[a-z]*',regex=True)]
# Out:
#        #                      Name    Type 1  Type 2  Total   HP  Attack  \
# 25    20                  Raticate    Normal     NaN    413   55      81
# 64    59                  Arcanine      Fire     NaN    555   90     110
# 237  219                  Magcargo      Fire    Rock    410   50      50
# 314  290                   Nincada       Bug  Ground    266   31      45
# 325  301                  Delcatty    Normal     NaN    380   70      65
# 372  340                  Whiscash     Water  Ground    468  110      78
# 404  369                 Relicanth     Water    Rock    485  100      90
# 497  448                   Lucario  Fighting   Steel    525   70     110
# 498  448       LucarioMega Lucario  Fighting   Steel    625   70     145
# 589  530                 Excadrill    Ground   Steel    508  110     135
# 650  589                Escavalier       Bug   Steel    495   70     135
# 698  637                 Volcarona       Bug    Fire    550   85      60
# ...
